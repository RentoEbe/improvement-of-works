# %% [markdown]
# ## データベース操作
# パンとソーセージを保存するデータベース
# COLUM
# 日付（キー)　曜日　パンの保存数　ソーセージの保存数

# %%
# 現在日時の取得
import datetime
now = datetime.datetime.now()
now_list = map(str, [now.year, now.month, now.day])
"".join(now_list)
# Out:
# '2026616'

# %%
a = now.__str__()
a_list = a.split(" ")

# %%
now_day = int(a_list[0].replace("-", ""))
print(now_day)
# Out:
# 20260616

# %%
today = str(datetime.date.today()).replace("-", "")

# %%
today_day = datetime.date.today()
print(today_day.strftime("%Y年%m月%d日"))
print(today_day)
# Out:
# 2026年06月16日
# 2026-06-16

# %%
n = datetime.datetime.now()
print(n.__str__())
date_list = n.__str__().split(" ")
now_day = int(date_list[0].replace("-", ""))
print(now_day)
# Out:
# 2026-06-16 14:37:58.123436
# 20260616

# %%
today = datetime.datetime.now()
print(today.year)
print(today.month)
print(today.day)
print(today.weekday())
print("{0.year}{1}{0.month}{1}{0.day}".format(today, "/"))
date_list = today.__str__().split(" ")
def get_today_date():
    """
    get today's date:
    :return: today's date which type is integer ex)20261023
    """

    today_date = int(date_list[0].replace("-", ""))
    print(today_date)

    return today_date

print(get_today_date())
# Out:
# 2026
# 6
# 16
# 1
# 2026/6/16
# 20260616
# 20260616

# %%
from datetime import date
print(type(today.weekday()))
week_day_list_ja = ['月', '火', '水', '木', '金', '土', '日']
print(week_day_list_ja[today.weekday()])
# Out:
# <class 'int'>
# 火

# %%
class Myname:
    def __init__(self, name):
        self.name_first = name

ebe = Myname("ebe")
print("{0.1_first}".format(ebe, name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       2     def __init__(self, name):
#       3         self.name_first = name
#       4
#       5 ebe = Myname("ebe")
# ----> 6 print("{0.1_first}".format(ebe, name))
#       7
#
# NameError: name 'name' is not defined

# %%
import math
class Thawing:
    def __init__(self, loaf, sausage):
        self.loaf = loaf
        self.sausage = sausage
        self.loaf_bags = 0
        self.sausage_bags = 0


    def thawing(self):
        # 入力値が割り切れないときは、解凍数が目安を上回るために整数値+1袋する
        number_of_loaf_bags = math.ceil(self.loaf / 6)
        number_of_sausage_bags = math.ceil(self. sausage / 10)
        print(f"{number_of_loaf_bags}{number_of_sausage_bags}")

x = Thawing(100, 100)
x.thawing()
# Out:
# 1710

# %%
class Thawing:
    def __init__(self, loaf, sausage):
        self.loaf = loaf
        self.sausage = sausage
        self.loaf_bags = 0
        self.sausage_bags = 0


    def thawing(self):
        # 入力値が割り切れないときは、解凍数が目安を上回るために整数値+1袋する
        number_of_loaf_bags = math.ceil(self.loaf / 6)
        number_of_sausage_bags = math.ceil(self. sausage / 10)

        self.loaf_bags = number_of_loaf_bags
        self.sausage_bags = number_of_sausage_bags


    def show_log(self):

        """
        it prints out the today's thawing and sausage bags
        :return: None
        """
        thaw_dict = {"sausage": self.sausage, "sausage_bags": self.sausage_bags, "loaf": self.loaf, "loaf_bags": self.loaf_bags}
        for key, value in thaw_dict.items():
            print(f"{format(key, '^12')} : {value}")

x = Thawing(100, 100)
x.thawing()
x.show_log()
# Out:
#   sausage    : 100
# sausage_bags : 10
#     loaf     : 100
#  loaf_bags   : 17
